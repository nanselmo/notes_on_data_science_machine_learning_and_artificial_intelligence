# %% [markdown]
# Title: Generate Tweets Using Markov Chains
# Slug: generate_tweets_using_markov_chain
# Summary: Generate Tweets Using Markov Chains
# Date: 2016-11-01 12:00
# Category: Python
# Tags: Other
# Authors: Chris Albon

# %% [markdown]
# ## Preliminaries

# %%
import markovify

# %% [markdown]
# ## Load Corpus

# %% [markdown]
# The corpus I am using is just one I found online. The corpus you choose is central to generating realistic text.

# %%
# Get raw text as string
with open("brown.txt") as f:
    text = f.read()

# %% [markdown]
# ## Build Markov Chain

# %%
# Build the model.
text_model = markovify.Text(text)

# %% [markdown]
# # Generate One Tweet

# %%
# Print three randomly-generated sentences of no more than 140 characters
for i in range(3):
    print(text_model.make_short_sentence(140))
# Out:
# Smiling at his shoulder.
# Fury and Caper worked in naturalistic color.
# It would be made a great number of policy guidance.
